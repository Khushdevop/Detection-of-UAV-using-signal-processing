# %%
from math import sqrt
from numpy import concatenate
from matplotlib import pyplot
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
import pandas as pd
import matplotlib.pyplot as plt
from numpy import array
import numpy as np
from sklearn import metrics

# %%
df1 = pd.read_csv(r"C:\Users\student\Desktop\ccsv\stat_ble\Approximate_coefficients\cA-ble-combined-files.csv")
df1.drop('Unnamed: 0',axis=1,inplace=True)
df1.dropna(inplace=True)
df1.isnull().sum()
df1.drop(df1[df1['Labels'] == 'Labels'].index, inplace = True)
df1.drop("Labels",axis=1,inplace=True)
df2 = pd.read_csv(r"C:\Users\student\Desktop\ccsv\stat_dji_fly\Approximate_coefficients\cA-dji-fly-combined-files.csv")
df2.drop('Unnamed: 0',axis=1,inplace=True)
df2.dropna(inplace=True)
df2.isnull().sum()
df2.drop(df2[df2['Labels'] == 'Labels'].index, inplace = True)
df2.drop("Labels",axis=1,inplace=True)
df3 = pd.read_csv(r"C:\Users\student\Desktop\ccsv\stat_dji_vid\Approximate_coefficients\cA-dji-vid-combined-files.csv")
df3.drop('Unnamed: 0',axis=1,inplace=True)
df3.dropna(inplace=True)
df3.isnull().sum()
df3.drop(df3[df3['Labels'] == 'Labels'].index, inplace = True)
df3.drop("Labels",axis=1,inplace=True)
dfa = pd.concat([df1, df2,df3], axis=0, ignore_index=True)
# Out:
# C:\Users\student\AppData\Local\Temp\ipykernel_12800\364653728.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1 = pd.read_csv(r"C:\Users\student\Desktop\ccsv\stat_ble\Approximate_coefficients\cA-ble-combined-files.csv")
# C:\Users\student\AppData\Local\Temp\ipykernel_12800\364653728.py:7: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2 = pd.read_csv(r"C:\Users\student\Desktop\ccsv\stat_dji_fly\Approximate_coefficients\cA-dji-fly-combined-files.csv")
# C:\Users\student\AppData\Local\Temp\ipykernel_12800\364653728.py:13: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df3 = pd.read_csv(r"C:\Users\student\Desktop\ccsv\stat_dji_vid\Approximate_coefficients\cA-dji-vid-combined-files.csv")

# %%
df4 = pd.read_csv(r"C:\Users\student\Desktop\ccsv\stat_ble\Descriptive_coefficients\cD-ble-combined-files.csv")
df4.drop('Unnamed: 0',axis=1,inplace=True)
df4.dropna(inplace=True)
df4.isnull().sum()
df4.drop(df4[df4['Labels'] == 'Labels'].index, inplace = True)

df5 = pd.read_csv(r"C:\Users\student\Desktop\ccsv\stat_dji_fly\Descriptive_coefficients\cD-dji-fly-combined-files.csv")
df5.drop('Unnamed: 0',axis=1,inplace=True)
df5.dropna(inplace=True)
df5.isnull().sum()
df5.drop(df5[df5['Labels'] == 'Labels'].index, inplace = True)

df6 = pd.read_csv(r"C:\Users\student\Desktop\ccsv\stat_dji_vid\Descriptive_coefficients\cD-dji-vid-combined-files.csv")
df6.drop('Unnamed: 0',axis=1,inplace=True)
df6.dropna(inplace=True)
df6.isnull().sum()
df6.drop(df6[df6['Labels'] == 'Labels'].index, inplace = True)
dfb = pd.concat([df4, df5,df6], axis=0, ignore_index=True)
# Out:
# C:\Users\student\AppData\Local\Temp\ipykernel_12800\507689285.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df4 = pd.read_csv(r"C:\Users\student\Desktop\ccsv\stat_ble\Descriptive_coefficients\cD-ble-combined-files.csv")
# C:\Users\student\AppData\Local\Temp\ipykernel_12800\507689285.py:7: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df5 = pd.read_csv(r"C:\Users\student\Desktop\ccsv\stat_dji_fly\Descriptive_coefficients\cD-dji-fly-combined-files.csv")
# C:\Users\student\AppData\Local\Temp\ipykernel_12800\507689285.py:13: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df6 = pd.read_csv(r"C:\Users\student\Desktop\ccsv\stat_dji_vid\Descriptive_coefficients\cD-dji-vid-combined-files.csv")

# %%
df = pd.concat([dfa, dfb], axis=1, ignore_index=True)
df
# Out:
#                           0                      1                      2   \
# 0       -0.42204765250281806   0.002196437711138652  -0.010192647376830328
# 1       -0.03768653533307109   0.005900599613821633  -0.010031562868760889
# 2       -0.41053378469502677   0.003815845176130709   -0.01016063895066021
# 3         -0.540285457367073  0.0029782206252727487  -0.010156305639650438
# 4       -0.13947545639468562  0.0029782206252727487   -0.01012554062059137
# ...                      ...                    ...                    ...
# 699995    -1.580033529698243     0.2859091800261839   -0.00482820193107342
# 699996   -1.5732519228583344     0.2859091800261839  -0.008140452336125198
# 699997    -1.532651227797683     0.2859091800261839  -0.005443137480228173
# 699998   -1.5682506771110056     0.2859091800261839  -0.006284693282311494
# 699999   -1.5843615662161386     0.2859091800261839  -0.004114828744701838
#
#                            3                      4                      5   \
# 0       0.0035010063352879884  -0.010274861157190982  0.0030154483830886576
# 1       0.0038150919900910188  -0.010079415428657458  0.0031922802327142286
# 2       0.0037122017462590533  -0.010163177883743255  0.0033132704456159327
# 3        0.003953902540971516    -0.0101445640048353  0.0035552508714193423
# 4         0.00341543675549119  -0.010163177883743255  0.0028758442912789972
# ...                       ...                    ...                    ...
# 699995     0.2010356901581723   0.005118816699687528    0.22011842502601806
# 699996    0.19875643022215567  -0.007482779320997782    0.21958792947714134
# 699997    0.19548249652555277  0.0027269332600153642     0.2108114855720407
# 699998     0.1988710955164382  0.0008562384297659195     0.2166097088518686
# 699999    0.20220723490220316   0.007659611170623349     0.2209281287585141
#
#                            6                     7                       8   \
# 0       -0.021815466080122886  0.011064454428858792     0.03288525887956754
# 1        -0.02470061731085586  0.011123746873907693    0.023238327537483314
# 2       -0.024086359306893353  0.011135143772678081   -0.062421261440778836
# 3        -0.02442140912723654  0.011244800528609548  -0.0049853428150490806
# 4       -0.023137051482587663  0.011000367075389893     0.03506742821964078
# ...                       ...                   ...                     ...
# 699995    -0.3046719699654022   0.21935988250867566   -0.028188399861477132
# 699996    -0.3046719699654022   0.21770953056754086   -0.007857379224396702
# 699997    -0.3046719699654022   0.21505195212358802    -0.02324485939261929
# 699998    -0.3046719699654022   0.21739288362928408   -0.018548067159849295
# 699999    -0.3046719699654022   0.22031660273228781    -0.03242589121276438
#
#                           9   ...                       13  \
# 0       0.004304891550304923  ...  -1.8316056845427267e-06
# 1       0.004806817130375256  ...    9.158028422713633e-07
# 2       0.004555528833465773  ...    7.371096047549982e-07
# 3       0.004826488856531453  ...   -8.190106719499283e-08
# 4       0.004299011855540309  ...  -1.9879622673695697e-06
# ...                      ...  ...                      ...
# 699995   0.21930674070883646  ...   2.7131589896234936e-05
# 699996   0.21755728610116065  ...    -4.09133058396844e-05
# 699997   0.21498305599869327  ...   3.3467754276502324e-05
# 699998   0.21730202135047613  ...   -9.705276462607581e-05
# 699999   0.22027817328073654  ...  -2.4317171405352566e-05
#
#                            14                       15                     16  \
# 0       0.0015451040292182472  -1.8613878907954885e-05   0.001340199281372737
# 1       0.0016795520170059916    4.653469726988678e-05  0.0014053478575505787
# 2       0.0016352328001899214                      0.0  0.0014332686759125101
# 3       0.0017778710078695493   -1.861387890795467e-05  0.0015728727677221705
# 4       0.0015277282204499833    9.306939453977009e-06   0.001275050705194894
# ...                       ...                      ...                    ...
# 699995     0.0717440447929487                      0.0    0.07549789285066419
# 699996     0.0717004871488416                      0.0     0.0758608634893693
# 699997    0.06976368415972886                      0.0    0.06621887421504877
# 699998     0.0712366793503441                      0.0    0.07374818823331644
# 699999    0.07158152100615414                      0.0     0.0753675956983085
#
#                            17                     18                     19  \
# 0       -0.006012282887269361  0.0019073609655378852   -0.02196003599027788
# 1       -0.006384560465428455  0.0021135396160106112  -0.019858488238713414
# 2       -0.006812679680311413  0.0020122099693063744   -0.00656864322334498
# 3       -0.006272877191980728    0.00216064996271806    0.02661407824791601
# 4       -0.005733074703650041  0.0019243521353933463    0.02514221223982336
# ...                       ...                    ...                    ...
# 699995    -0.1531177678968352    0.09072060145710933    0.03059691203403007
# 699996   -0.14807340671277947    0.08938424143248361   0.022667593885058106
# 699997    -0.1522429155881613    0.08898218869997132    0.03308924083751441
# 699998   -0.15174034085764657     0.0897428662602625    0.02835897299347792
# 699999   -0.15255935152959654    0.09117383979601845   0.036978906052908204
#
#                            20                      21                    22
# 0       0.0019073600861080834  3.6380224980782356e-06          BLE-IPhone6S
# 1        0.002113539417600591   4.467048869751445e-06          BLE-IPhone6S
# 2       0.0020122098342979498   4.048988417245382e-06          BLE-IPhone6S
# 3        0.002160649961165803  4.6684082546857855e-06          BLE-IPhone6S
# 4       0.0019243511085555464  3.7031271889989607e-06          BLE-IPhone6S
# ...                       ...                     ...                   ...
# 699995    0.09072059740002011    0.008230226792616537  DJI-INSPIRE-VIDEOING
# 699996    0.08938423206898387    0.007989540942561964  DJI-INSPIRE-VIDEOING
# 699997    0.08898218240606759    0.007917828785746685  DJI-INSPIRE-VIDEOING
# 699998    0.08974281378120576    0.008053772625368173  DJI-INSPIRE-VIDEOING
# 699999    0.09117383655317549    0.008312668471825158  DJI-INSPIRE-VIDEOING
#
# [700000 rows x 23 columns]

# %%
#df.iloc[:700000,-1]=df.iloc[:700000,-1].replace(regex='DJI-INSPIRE-VIDEOING', value='BLE')

# %%
df=df.rename(columns={22:'Labels'})

# %%
#df = df.iloc[:,1:]

# %%
#df.loc[250:,'Labels']=1

# %%
#df=df.rename(columns={22:'Labels'})

# %%
df['Labels'].unique()
# Out:
# array(['BLE-IPhone6S', 'DJI-INSPIRE-FLYING', 'DJI-INSPIRE-VIDEOING'],
#       dtype=object)

# %%
from sklearn import preprocessing

label_encoder = preprocessing.LabelEncoder()
df['Labels']= label_encoder.fit_transform(df['Labels'])
df['Labels'].unique()
# Out:
# array([0, 1, 2])

# %%
df.shape
# Out:
# (700000, 23)

# %%
#df.drop(columns=['Unnamed: 0'],inplace=True, axis=1)

# %%
df
# Out:
#                            0                      1                      2  \
# 0       -0.42204765250281806   0.002196437711138652  -0.010192647376830328
# 1       -0.03768653533307109   0.005900599613821633  -0.010031562868760889
# 2       -0.41053378469502677   0.003815845176130709   -0.01016063895066021
# 3         -0.540285457367073  0.0029782206252727487  -0.010156305639650438
# 4       -0.13947545639468562  0.0029782206252727487   -0.01012554062059137
# ...                      ...                    ...                    ...
# 699995    -1.580033529698243     0.2859091800261839   -0.00482820193107342
# 699996   -1.5732519228583344     0.2859091800261839  -0.008140452336125198
# 699997    -1.532651227797683     0.2859091800261839  -0.005443137480228173
# 699998   -1.5682506771110056     0.2859091800261839  -0.006284693282311494
# 699999   -1.5843615662161386     0.2859091800261839  -0.004114828744701838
#
#                             3                      4                      5  \
# 0       0.0035010063352879884  -0.010274861157190982  0.0030154483830886576
# 1       0.0038150919900910188  -0.010079415428657458  0.0031922802327142286
# 2       0.0037122017462590533  -0.010163177883743255  0.0033132704456159327
# 3        0.003953902540971516    -0.0101445640048353  0.0035552508714193423
# 4         0.00341543675549119  -0.010163177883743255  0.0028758442912789972
# ...                       ...                    ...                    ...
# 699995     0.2010356901581723   0.005118816699687528    0.22011842502601806
# 699996    0.19875643022215567  -0.007482779320997782    0.21958792947714134
# 699997    0.19548249652555277  0.0027269332600153642     0.2108114855720407
# 699998     0.1988710955164382  0.0008562384297659195     0.2166097088518686
# 699999    0.20220723490220316   0.007659611170623349     0.2209281287585141
#
#                             6                     7                       8  \
# 0       -0.021815466080122886  0.011064454428858792     0.03288525887956754
# 1        -0.02470061731085586  0.011123746873907693    0.023238327537483314
# 2       -0.024086359306893353  0.011135143772678081   -0.062421261440778836
# 3        -0.02442140912723654  0.011244800528609548  -0.0049853428150490806
# 4       -0.023137051482587663  0.011000367075389893     0.03506742821964078
# ...                       ...                   ...                     ...
# 699995    -0.3046719699654022   0.21935988250867566   -0.028188399861477132
# 699996    -0.3046719699654022   0.21770953056754086   -0.007857379224396702
# 699997    -0.3046719699654022   0.21505195212358802    -0.02324485939261929
# 699998    -0.3046719699654022   0.21739288362928408   -0.018548067159849295
# 699999    -0.3046719699654022   0.22031660273228781    -0.03242589121276438
#
#                            9  ...                       13  \
# 0       0.004304891550304923  ...  -1.8316056845427267e-06
# 1       0.004806817130375256  ...    9.158028422713633e-07
# 2       0.004555528833465773  ...    7.371096047549982e-07
# 3       0.004826488856531453  ...   -8.190106719499283e-08
# 4       0.004299011855540309  ...  -1.9879622673695697e-06
# ...                      ...  ...                      ...
# 699995   0.21930674070883646  ...   2.7131589896234936e-05
# 699996   0.21755728610116065  ...    -4.09133058396844e-05
# 699997   0.21498305599869327  ...   3.3467754276502324e-05
# 699998   0.21730202135047613  ...   -9.705276462607581e-05
# 699999   0.22027817328073654  ...  -2.4317171405352566e-05
#
#                            14                       15                     16  \
# 0       0.0015451040292182472  -1.8613878907954885e-05   0.001340199281372737
# 1       0.0016795520170059916    4.653469726988678e-05  0.0014053478575505787
# 2       0.0016352328001899214                      0.0  0.0014332686759125101
# 3       0.0017778710078695493   -1.861387890795467e-05  0.0015728727677221705
# 4       0.0015277282204499833    9.306939453977009e-06   0.001275050705194894
# ...                       ...                      ...                    ...
# 699995     0.0717440447929487                      0.0    0.07549789285066419
# 699996     0.0717004871488416                      0.0     0.0758608634893693
# 699997    0.06976368415972886                      0.0    0.06621887421504877
# 699998     0.0712366793503441                      0.0    0.07374818823331644
# 699999    0.07158152100615414                      0.0     0.0753675956983085
#
#                            17                     18                     19  \
# 0       -0.006012282887269361  0.0019073609655378852   -0.02196003599027788
# 1       -0.006384560465428455  0.0021135396160106112  -0.019858488238713414
# 2       -0.006812679680311413  0.0020122099693063744   -0.00656864322334498
# 3       -0.006272877191980728    0.00216064996271806    0.02661407824791601
# 4       -0.005733074703650041  0.0019243521353933463    0.02514221223982336
# ...                       ...                    ...                    ...
# 699995    -0.1531177678968352    0.09072060145710933    0.03059691203403007
# 699996   -0.14807340671277947    0.08938424143248361   0.022667593885058106
# 699997    -0.1522429155881613    0.08898218869997132    0.03308924083751441
# 699998   -0.15174034085764657     0.0897428662602625    0.02835897299347792
# 699999   -0.15255935152959654    0.09117383979601845   0.036978906052908204
#
#                            20                      21 Labels
# 0       0.0019073600861080834  3.6380224980782356e-06      0
# 1        0.002113539417600591   4.467048869751445e-06      0
# 2       0.0020122098342979498   4.048988417245382e-06      0
# 3        0.002160649961165803  4.6684082546857855e-06      0
# 4       0.0019243511085555464  3.7031271889989607e-06      0
# ...                       ...                     ...    ...
# 699995    0.09072059740002011    0.008230226792616537      2
# 699996    0.08938423206898387    0.007989540942561964      2
# 699997    0.08898218240606759    0.007917828785746685      2
# 699998    0.08974281378120576    0.008053772625368173      2
# 699999    0.09117383655317549    0.008312668471825158      2
#
# [700000 rows x 23 columns]

# %%
#df.to_csv(r"C:\Users\student\Desktop\ktt\1a.csv")

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaledX = scaler.fit_transform(df.drop(columns=['Labels'], axis=1))

# %%
y = df['Labels']
scaledX = scaledX.reshape(-1,22,1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(scaledX,y,test_size=0.20,random_state=0)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (560000, 22, 1)
# (140000, 22, 1)
# (560000,)
# (140000,)

# %%
import tensorflow as tf

# %%
model = Sequential()

model.add(LSTM(64,return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(LSTM(64,return_sequences=False, input_shape=(X_train.shape[1], X_train.shape[2])))

model.add(Dense(3,activation='softmax'))

model.compile(loss='sparse_categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
#model.compile(loss = "mean_absolute_percentage_error", optimizer = 'adam',metrics = ['custom_metrics'])

model.summary()
# fit network
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 22, 64)            16896
#
#  lstm_1 (LSTM)               (None, 64)                33024
#
#  dense (Dense)               (None, 3)                 195
#
# =================================================================
# Total params: 50,115
# Trainable params: 50,115
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(X_train, y_train, epochs=100, batch_size=10, validation_data=(X_test, y_test), verbose=2, shuffle=False)


# plot history
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()
# Out:
# Epoch 1/100
# 56000/56000 - 1344s - loss: 0.2503 - accuracy: 0.9141 - val_loss: 0.1984 - val_accuracy: 0.9295 - 1344s/epoch - 24ms/step
# Epoch 2/100
# 56000/56000 - 1395s - loss: 0.1935 - accuracy: 0.9312 - val_loss: 0.1853 - val_accuracy: 0.9326 - 1395s/epoch - 25ms/step
# Epoch 3/100
# 56000/56000 - 1385s - loss: 0.1814 - accuracy: 0.9346 - val_loss: 0.1882 - val_accuracy: 0.9303 - 1385s/epoch - 25ms/step
# Epoch 4/100
# 56000/56000 - 1389s - loss: 0.1739 - accuracy: 0.9367 - val_loss: 0.1722 - val_accuracy: 0.9358 - 1389s/epoch - 25ms/step
# Epoch 5/100
# 56000/56000 - 1388s - loss: 0.1670 - accuracy: 0.9384 - val_loss: 0.1625 - val_accuracy: 0.9388 - 1388s/epoch - 25ms/step
# Epoch 6/100
# 56000/56000 - 1305s - loss: 0.1597 - accuracy: 0.9403 - val_loss: 0.1785 - val_accuracy: 0.9342 - 1305s/epoch - 23ms/step
# Epoch 7/100
# 56000/56000 - 1253s - loss: 0.1513 - accuracy: 0.9429 - val_loss: 0.1504 - val_accuracy: 0.9425 - 1253s/epoch - 22ms/step
# Epoch 8/100
# 56000/56000 - 1256s - loss: 0.1441 - accuracy: 0.9454 - val_loss: 0.1487 - val_accuracy: 0.9423 - 1256s/epoch - 22ms/step
# Epoch 9/100
# 56000/56000 - 1248s - loss: 0.1391 - accuracy: 0.9472 - val_loss: 0.1365 - val_accuracy: 0.9471 - 1248s/epoch - 22ms/step
# Epoch 10/100
# 56000/56000 - 1327s - loss: 0.1362 - accuracy: 0.9482 - val_loss: 0.1578 - val_accuracy: 0.9403 - 1327s/epoch - 24ms/step
# Epoch 11/100
# 56000/56000 - 1301s - loss: 0.1336 - accuracy: 0.9493 - val_loss: 0.1299 - val_accuracy: 0.9492 - 1301s/epoch - 23ms/step
# Epoch 12/100
# 56000/56000 - 1248s - loss: 0.1317 - accuracy: 0.9500 - val_loss: 0.1321 - val_accuracy: 0.9482 - 1248s/epoch - 22ms/step
# Epoch 13/100
# 56000/56000 - 1244s - loss: 0.1302 - accuracy: 0.9506 - val_loss: 0.1347 - val_accuracy: 0.9483 - 1244s/epoch - 22ms/step
# Epoch 14/100
# 56000/56000 - 1234s - loss: 0.1285 - accuracy: 0.9511 - val_loss: 0.1303 - val_accuracy: 0.9491 - 1234s/epoch - 22ms/step
# Epoch 15/100
# 56000/56000 - 1232s - loss: 0.1273 - accuracy: 0.9518 - val_loss: 0.1266 - val_accuracy: 0.9511 - 1232s/epoch - 22ms/step
# Epoch 16/100
# 56000/56000 - 1236s - loss: 0.1262 - accuracy: 0.9522 - val_loss: 0.1277 - val_accuracy: 0.9514 - 1236s/epoch - 22ms/step
# Epoch 17/100
# 56000/56000 - 1234s - loss: 0.1253 - accuracy: 0.9524 - val_loss: 0.1240 - val_accuracy: 0.9525 - 1234s/epoch - 22ms/step
# Epoch 18/100
# 56000/56000 - 1234s - loss: 0.1241 - accuracy: 0.9531 - val_loss: 0.1222 - val_accuracy: 0.9536 - 1234s/epoch - 22ms/step
# Epoch 19/100
# 56000/56000 - 1231s - loss: 0.1235 - accuracy: 0.9533 - val_loss: 0.1219 - val_accuracy: 0.9534 - 1231s/epoch - 22ms/step
# Epoch 20/100
# 56000/56000 - 1226s - loss: 0.1241 - accuracy: 0.9531 - val_loss: 0.1530 - val_accuracy: 0.9428 - 1226s/epoch - 22ms/step
# Epoch 21/100
# 56000/56000 - 1226s - loss: 0.1278 - accuracy: 0.9519 - val_loss: 0.1430 - val_accuracy: 0.9452 - 1226s/epoch - 22ms/step
# Epoch 22/100
# 56000/56000 - 1221s - loss: 0.1220 - accuracy: 0.9538 - val_loss: 0.1254 - val_accuracy: 0.9525 - 1221s/epoch - 22ms/step
# Epoch 23/100
# 56000/56000 - 1216s - loss: 0.1208 - accuracy: 0.9543 - val_loss: 0.1276 - val_accuracy: 0.9521 - 1216s/epoch - 22ms/step
# Epoch 24/100
# 56000/56000 - 1221s - loss: 0.1206 - accuracy: 0.9544 - val_loss: 0.1203 - val_accuracy: 0.9539 - 1221s/epoch - 22ms/step
# Epoch 25/100
# 56000/56000 - 1223s - loss: 0.1196 - accuracy: 0.9547 - val_loss: 0.1210 - val_accuracy: 0.9538 - 1223s/epoch - 22ms/step
# Epoch 26/100
# 56000/56000 - 1223s - loss: 0.1191 - accuracy: 0.9549 - val_loss: 0.1183 - val_accuracy: 0.9550 - 1223s/epoch - 22ms/step
# Epoch 27/100
# 56000/56000 - 1222s - loss: 0.1187 - accuracy: 0.9552 - val_loss: 0.1173 - val_accuracy: 0.9554 - 1222s/epoch - 22ms/step
# Epoch 28/100
# 56000/56000 - 1229s - loss: 0.1183 - accuracy: 0.9552 - val_loss: 0.1209 - val_accuracy: 0.9543 - 1229s/epoch - 22ms/step
# Epoch 29/100
# 56000/56000 - 1227s - loss: 0.1178 - accuracy: 0.9553 - val_loss: 0.1172 - val_accuracy: 0.9552 - 1227s/epoch - 22ms/step
# Epoch 30/100
# 56000/56000 - 1229s - loss: 0.1172 - accuracy: 0.9556 - val_loss: 0.1182 - val_accuracy: 0.9552 - 1229s/epoch - 22ms/step
# Epoch 31/100
# 56000/56000 - 1227s - loss: 0.1166 - accuracy: 0.9559 - val_loss: 0.1170 - val_accuracy: 0.9556 - 1227s/epoch - 22ms/step
# Epoch 32/100
# 56000/56000 - 1225s - loss: 0.1163 - accuracy: 0.9560 - val_loss: 0.1215 - val_accuracy: 0.9543 - 1225s/epoch - 22ms/step
# Epoch 33/100
# 56000/56000 - 1230s - loss: 0.1162 - accuracy: 0.9560 - val_loss: 0.1179 - val_accuracy: 0.9551 - 1230s/epoch - 22ms/step
# Epoch 34/100
# 56000/56000 - 1237s - loss: 0.1160 - accuracy: 0.9561 - val_loss: 0.1213 - val_accuracy: 0.9541 - 1237s/epoch - 22ms/step
# Epoch 35/100
# 56000/56000 - 1235s - loss: 0.1156 - accuracy: 0.9563 - val_loss: 0.1179 - val_accuracy: 0.9558 - 1235s/epoch - 22ms/step
# Epoch 36/100
# 56000/56000 - 1233s - loss: 0.1154 - accuracy: 0.9563 - val_loss: 0.1177 - val_accuracy: 0.9555 - 1233s/epoch - 22ms/step
# Epoch 37/100
# 56000/56000 - 1232s - loss: 0.1148 - accuracy: 0.9564 - val_loss: 0.1177 - val_accuracy: 0.9552 - 1232s/epoch - 22ms/step
# Epoch 38/100
# 56000/56000 - 1232s - loss: 0.1155 - accuracy: 0.9562 - val_loss: 0.1173 - val_accuracy: 0.9557 - 1232s/epoch - 22ms/step
# Epoch 39/100
# 56000/56000 - 1234s - loss: 0.1138 - accuracy: 0.9568 - val_loss: 0.1176 - val_accuracy: 0.9557 - 1234s/epoch - 22ms/step
# Epoch 40/100
# 56000/56000 - 1215s - loss: 0.1143 - accuracy: 0.9568 - val_loss: 0.1165 - val_accuracy: 0.9558 - 1215s/epoch - 22ms/step
# Epoch 41/100
# 56000/56000 - 1119s - loss: 0.1140 - accuracy: 0.9570 - val_loss: 0.1166 - val_accuracy: 0.9559 - 1119s/epoch - 20ms/step
# Epoch 42/100
# 56000/56000 - 1122s - loss: 0.1141 - accuracy: 0.9568 - val_loss: 0.1153 - val_accuracy: 0.9561 - 1122s/epoch - 20ms/step
# Epoch 43/100
# 56000/56000 - 1133s - loss: 0.1143 - accuracy: 0.9569 - val_loss: 0.1158 - val_accuracy: 0.9561 - 1133s/epoch - 20ms/step
# Epoch 44/100
# 56000/56000 - 1127s - loss: 0.1138 - accuracy: 0.9571 - val_loss: 0.1192 - val_accuracy: 0.9550 - 1127s/epoch - 20ms/step
# Epoch 45/100
# 56000/56000 - 1122s - loss: 0.1133 - accuracy: 0.9571 - val_loss: 0.1158 - val_accuracy: 0.9564 - 1122s/epoch - 20ms/step
# Epoch 46/100
# 56000/56000 - 1124s - loss: 0.1141 - accuracy: 0.9571 - val_loss: 0.1138 - val_accuracy: 0.9572 - 1124s/epoch - 20ms/step
# Epoch 47/100
# 56000/56000 - 1142s - loss: 0.1602 - accuracy: 0.9455 - val_loss: 0.1920 - val_accuracy: 0.9341 - 1142s/epoch - 20ms/step
# Epoch 48/100
# 56000/56000 - 1126s - loss: 0.1580 - accuracy: 0.9439 - val_loss: 0.1195 - val_accuracy: 0.9542 - 1126s/epoch - 20ms/step
# Epoch 49/100
# 56000/56000 - 1148s - loss: 0.1606 - accuracy: 0.9428 - val_loss: 0.1210 - val_accuracy: 0.9534 - 1148s/epoch - 21ms/step
# Epoch 50/100
# 56000/56000 - 1120s - loss: 0.1160 - accuracy: 0.9563 - val_loss: 0.1203 - val_accuracy: 0.9539 - 1120s/epoch - 20ms/step
# Epoch 51/100
# 56000/56000 - 1134s - loss: 0.1142 - accuracy: 0.9570 - val_loss: 0.1148 - val_accuracy: 0.9564 - 1134s/epoch - 20ms/step
# Epoch 52/100
# 56000/56000 - 1141s - loss: 0.1132 - accuracy: 0.9573 - val_loss: 0.1188 - val_accuracy: 0.9547 - 1141s/epoch - 20ms/step
# Epoch 53/100
# 56000/56000 - 1153s - loss: 0.1131 - accuracy: 0.9573 - val_loss: 0.1147 - val_accuracy: 0.9566 - 1153s/epoch - 21ms/step
# Epoch 54/100
# 56000/56000 - 1131s - loss: 0.1127 - accuracy: 0.9576 - val_loss: 0.1123 - val_accuracy: 0.9575 - 1131s/epoch - 20ms/step
# Epoch 55/100
# 56000/56000 - 1156s - loss: 0.1126 - accuracy: 0.9578 - val_loss: 0.1148 - val_accuracy: 0.9565 - 1156s/epoch - 21ms/step
# Epoch 56/100
# 56000/56000 - 1138s - loss: 0.1120 - accuracy: 0.9578 - val_loss: 0.1147 - val_accuracy: 0.9568 - 1138s/epoch - 20ms/step
# Epoch 57/100
# 56000/56000 - 1139s - loss: 0.1120 - accuracy: 0.9579 - val_loss: 0.1150 - val_accuracy: 0.9573 - 1139s/epoch - 20ms/step
# Epoch 58/100
# 56000/56000 - 1138s - loss: 0.1117 - accuracy: 0.9579 - val_loss: 0.1132 - val_accuracy: 0.9573 - 1138s/epoch - 20ms/step
# Epoch 59/100
# 56000/56000 - 1145s - loss: 0.1111 - accuracy: 0.9581 - val_loss: 0.1183 - val_accuracy: 0.9556 - 1145s/epoch - 20ms/step
# Epoch 60/100
# 56000/56000 - 1143s - loss: 0.1133 - accuracy: 0.9574 - val_loss: 0.1179 - val_accuracy: 0.9560 - 1143s/epoch - 20ms/step
# Epoch 61/100
# 56000/56000 - 1148s - loss: 0.1121 - accuracy: 0.9577 - val_loss: 0.1134 - val_accuracy: 0.9571 - 1148s/epoch - 21ms/step
# Epoch 62/100
# 56000/56000 - 1142s - loss: 0.1133 - accuracy: 0.9574 - val_loss: 0.1141 - val_accuracy: 0.9575 - 1142s/epoch - 20ms/step
# Epoch 63/100
# 56000/56000 - 1147s - loss: 0.1109 - accuracy: 0.9582 - val_loss: 0.1167 - val_accuracy: 0.9559 - 1147s/epoch - 20ms/step
# Epoch 64/100
# 56000/56000 - 1149s - loss: 0.1111 - accuracy: 0.9580 - val_loss: 0.1147 - val_accuracy: 0.9570 - 1149s/epoch - 21ms/step
# Epoch 65/100
# 56000/56000 - 1144s - loss: 0.1105 - accuracy: 0.9583 - val_loss: 0.1153 - val_accuracy: 0.9571 - 1144s/epoch - 20ms/step
# Epoch 66/100
# 56000/56000 - 1237s - loss: 0.1102 - accuracy: 0.9584 - val_loss: 0.1138 - val_accuracy: 0.9569 - 1237s/epoch - 22ms/step
# Epoch 67/100
# 56000/56000 - 1299s - loss: 0.1120 - accuracy: 0.9579 - val_loss: 0.1176 - val_accuracy: 0.9562 - 1299s/epoch - 23ms/step
# Epoch 68/100
# 56000/56000 - 1297s - loss: 0.1120 - accuracy: 0.9578 - val_loss: 0.1133 - val_accuracy: 0.9577 - 1297s/epoch - 23ms/step
# Epoch 69/100
# 56000/56000 - 1287s - loss: 0.2890 - accuracy: 0.9209 - val_loss: 0.2491 - val_accuracy: 0.9154 - 1287s/epoch - 23ms/step
# Epoch 70/100
# 56000/56000 - 1349s - loss: 0.2666 - accuracy: 0.9128 - val_loss: 0.2778 - val_accuracy: 0.9074 - 1349s/epoch - 24ms/step
# Epoch 71/100
# 56000/56000 - 1277s - loss: 0.2886 - accuracy: 0.9053 - val_loss: 0.3315 - val_accuracy: 0.8941 - 1277s/epoch - 23ms/step
# Epoch 72/100
# 56000/56000 - 1309s - loss: 0.2761 - accuracy: 0.9087 - val_loss: 0.2477 - val_accuracy: 0.9169 - 1309s/epoch - 23ms/step
# Epoch 73/100
# 56000/56000 - 1272s - loss: 0.2428 - accuracy: 0.9182 - val_loss: 0.2506 - val_accuracy: 0.9156 - 1272s/epoch - 23ms/step
# Epoch 74/100
# 56000/56000 - 1259s - loss: 0.2412 - accuracy: 0.9186 - val_loss: 0.2062 - val_accuracy: 0.9286 - 1259s/epoch - 22ms/step
# Epoch 75/100
# 56000/56000 - 1261s - loss: 0.2080 - accuracy: 0.9284 - val_loss: 0.1991 - val_accuracy: 0.9285 - 1261s/epoch - 23ms/step
# Epoch 76/100
# 56000/56000 - 1262s - loss: 0.1968 - accuracy: 0.9303 - val_loss: 0.1946 - val_accuracy: 0.9302 - 1262s/epoch - 23ms/step
# Epoch 77/100
# 56000/56000 - 1314s - loss: 0.1868 - accuracy: 0.9337 - val_loss: 0.1833 - val_accuracy: 0.9331 - 1314s/epoch - 23ms/step
# Epoch 78/100
# 56000/56000 - 1407s - loss: 0.1812 - accuracy: 0.9354 - val_loss: 0.1803 - val_accuracy: 0.9341 - 1407s/epoch - 25ms/step
# Epoch 79/100
# 56000/56000 - 1388s - loss: 0.1768 - accuracy: 0.9370 - val_loss: 0.1757 - val_accuracy: 0.9357 - 1388s/epoch - 25ms/step
# Epoch 80/100
# 56000/56000 - 1351s - loss: 0.1704 - accuracy: 0.9389 - val_loss: 0.1697 - val_accuracy: 0.9376 - 1351s/epoch - 24ms/step
# Epoch 81/100
# 56000/56000 - 1257s - loss: 0.1668 - accuracy: 0.9398 - val_loss: 0.1681 - val_accuracy: 0.9377 - 1257s/epoch - 22ms/step
# Epoch 82/100
# 56000/56000 - 1259s - loss: 0.1623 - accuracy: 0.9406 - val_loss: 0.1651 - val_accuracy: 0.9391 - 1259s/epoch - 22ms/step
# Epoch 83/100
# 56000/56000 - 1266s - loss: 0.1557 - accuracy: 0.9420 - val_loss: 0.1599 - val_accuracy: 0.9406 - 1266s/epoch - 23ms/step
# Epoch 84/100
# 56000/56000 - 1281s - loss: 0.1494 - accuracy: 0.9441 - val_loss: 0.1620 - val_accuracy: 0.9394 - 1281s/epoch - 23ms/step
# Epoch 85/100
# 56000/56000 - 1245s - loss: 0.1428 - accuracy: 0.9465 - val_loss: 0.1454 - val_accuracy: 0.9437 - 1245s/epoch - 22ms/step
# Epoch 86/100
# 56000/56000 - 1246s - loss: 0.1379 - accuracy: 0.9483 - val_loss: 0.1374 - val_accuracy: 0.9466 - 1246s/epoch - 22ms/step
# Epoch 87/100
# 56000/56000 - 1247s - loss: 0.1345 - accuracy: 0.9497 - val_loss: 0.1300 - val_accuracy: 0.9500 - 1247s/epoch - 22ms/step
# Epoch 88/100
# 56000/56000 - 1241s - loss: 0.1328 - accuracy: 0.9501 - val_loss: 0.1284 - val_accuracy: 0.9505 - 1241s/epoch - 22ms/step
# Epoch 89/100
# 56000/56000 - 1241s - loss: 0.1314 - accuracy: 0.9507 - val_loss: 0.1314 - val_accuracy: 0.9498 - 1241s/epoch - 22ms/step
# Epoch 90/100
# 56000/56000 - 1237s - loss: 0.1312 - accuracy: 0.9508 - val_loss: 0.1290 - val_accuracy: 0.9506 - 1237s/epoch - 22ms/step
# Epoch 91/100
# 56000/56000 - 1236s - loss: 0.1294 - accuracy: 0.9512 - val_loss: 0.1270 - val_accuracy: 0.9505 - 1236s/epoch - 22ms/step
# Epoch 92/100
# 56000/56000 - 1235s - loss: 0.1294 - accuracy: 0.9513 - val_loss: 0.1322 - val_accuracy: 0.9492 - 1235s/epoch - 22ms/step
# Epoch 93/100
# 56000/56000 - 1239s - loss: 0.1834 - accuracy: 0.9366 - val_loss: 0.1574 - val_accuracy: 0.9399 - 1239s/epoch - 22ms/step
# Epoch 94/100
# 56000/56000 - 1232s - loss: 0.1362 - accuracy: 0.9491 - val_loss: 0.1282 - val_accuracy: 0.9502 - 1232s/epoch - 22ms/step
# Epoch 95/100
# 56000/56000 - 1231s - loss: 0.1300 - accuracy: 0.9508 - val_loss: 0.1668 - val_accuracy: 0.9410 - 1231s/epoch - 22ms/step
# Epoch 96/100
# 56000/56000 - 1238s - loss: 0.1287 - accuracy: 0.9514 - val_loss: 0.1346 - val_accuracy: 0.9490 - 1238s/epoch - 22ms/step
# Epoch 97/100
# 56000/56000 - 1237s - loss: 0.1268 - accuracy: 0.9521 - val_loss: 0.1294 - val_accuracy: 0.9504 - 1237s/epoch - 22ms/step
# Epoch 98/100
# 56000/56000 - 1239s - loss: 0.1261 - accuracy: 0.9523 - val_loss: 0.1353 - val_accuracy: 0.9483 - 1239s/epoch - 22ms/step
# Epoch 99/100
# 56000/56000 - 1233s - loss: 0.1260 - accuracy: 0.9526 - val_loss: 0.1243 - val_accuracy: 0.9528 - 1233s/epoch - 22ms/step
# Epoch 100/100
# 56000/56000 - 1227s - loss: 0.1260 - accuracy: 0.9525 - val_loss: 0.1382 - val_accuracy: 0.9479 - 1227s/epoch - 22ms/step

# %%
pyplot.plot(history.history['accuracy'], label='train')
pyplot.plot(history.history['val_accuracy'], label='test')
pyplot.legend()
pyplot.show()

# %%
from matplotlib import pyplot

# %%
#y1_pred_train =model.predict(y_train) 

y_pred_test  = np.argmax(model.predict(X_test),axis=1)
y_pred_train = np.argmax(model.predict(X_train),axis=1)
# Out:
# 4375/4375 [==============================] - 54s 12ms/step
# 17500/17500 [==============================] - 258s 15ms/step

# %%
y_pred_test.shape
# Out:
# (140000,)

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

# %%
confusion_mtx = confusion_matrix(y_test, y_pred_test) 
# plot the confusion matrix
f,ax = plt.subplots(figsize=(8, 8))
sns.heatmap(confusion_mtx, annot=True, linewidths=0.01,cmap="Greens",linecolor="gray", fmt= '.1f',ax=ax)
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")
plt.show()

# %%
print(classification_report(y_test,y_pred_test))
print(classification_report(y_train,y_pred_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.97     70028
#            1       0.94      0.90      0.92     35145
#            2       0.97      0.90      0.93     34827
#
#     accuracy                           0.95    140000
#    macro avg       0.95      0.93      0.94    140000
# weighted avg       0.95      0.95      0.95    140000
#
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97    279972
#            1       0.94      0.90      0.92    139855
#            2       0.97      0.91      0.94    140173
#
#     accuracy                           0.95    560000
#    macro avg       0.95      0.93      0.94    560000
# weighted avg       0.95      0.95      0.95    560000
